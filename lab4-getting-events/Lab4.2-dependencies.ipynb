# %% [markdown]
# # Lab4.2: Detecting predicates and participants

# %% [markdown]
# Copyright, Vrije Universiteit Amsterdam, Faculty of Humanities, CLTL

# %% [markdown]
# In this notebook, we are going to look into the dependency relations generated by spaCy. You have already processed your documents using spaCy. Each text is split into sentences and for each sentence a syntactic parser tree is created.
#
# We are going to extract the main predicate that represents the root from these syntactic structures to represent an event and the depending constituents as possible participants and adjuncts.

# %% [markdown]
# ## 2. Finding predicates in text

# %%
import spacy
from spacy import displacy
# depending on how you installed spaCy, the name of the model might be different
nlp = spacy.load(name='en_core_web_sm') 
text = "John makes the cake . He got sick . He went to bed ."
doc = nlp(text)

# %%
displacy.render(doc, jupyter=True, style='dep')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6a6cac0d49b64d54a1a8dd6ad01a1229-0" class="displacy" width="1975" height="312.0" direction="ltr" style="max-width: none; height: 312.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">John</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="225">makes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="400">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">cake .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="925">got</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">sick .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1275">He</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1450">went</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="222.0">
#     <tspan class="displacy-word" fill="currentColor" x="1800">bed .</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-0" stroke-width="2px" d="M70,177.0 C70,89.5 220.0,89.5 220.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,179.0 L62,167.0 78,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-1" stroke-width="2px" d="M420,177.0 C420,89.5 570.0,89.5 570.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M420,179.0 L412,167.0 428,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-2" stroke-width="2px" d="M245,177.0 C245,2.0 575.0,2.0 575.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M575.0,179.0 L583.0,167.0 567.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-3" stroke-width="2px" d="M770,177.0 C770,89.5 920.0,89.5 920.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,179.0 L762,167.0 778,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-4" stroke-width="2px" d="M945,177.0 C945,89.5 1095.0,89.5 1095.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">acomp</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1095.0,179.0 L1103.0,167.0 1087.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-5" stroke-width="2px" d="M1295,177.0 C1295,89.5 1445.0,89.5 1445.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1295,179.0 L1287,167.0 1303,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-6" stroke-width="2px" d="M1470,177.0 C1470,89.5 1620.0,89.5 1620.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1620.0,179.0 L1628.0,167.0 1612.0,167.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-7" stroke-width="2px" d="M1645,177.0 C1645,89.5 1795.0,89.5 1795.0,177.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6a6cac0d49b64d54a1a8dd6ad01a1229-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M1795.0,179.0 L1803.0,167.0 1787.0,167.0" fill="currentColor"/>
# </g>
# </svg>

# %%
def get_predicate_subject_object(doc, rels={'nsubj', 'dobj', 'prep'}):
    """
    extract predicates with:
    -subject
    -object
    
    :param spacy.tokens.doc.Doc doc: spaCy object after processing text
    
    :rtype: list 
    :return: list of tuples (predicate, subject, object)
    """
    predicates = {}
    
    for token in doc:
        # we first check if we care about this dependency, as indicated by the input parameter "rels"
        if token.dep_ in rels:
            
            head = token.head  #points to the token that is the head of this token
            head_id = head.i
            
            # we check if we already have this head token
            # if not we create an entry with an empty dictionary for it
            if head_id not in predicates:
                predicates[head_id] = dict()
            
            # we are now sure it exists and we add to the head_id entry a dictionary entry for the dependency and the lemma
            predicates[head_id][token.dep_] = token.lemma_
            # note that we can only have one value per dependency relation
    
    # We next simplify the output to a list of tuples with the predicate lemma as the first, 
    # the subject as the second and the object as the third element
    output = []
    for pred_token, pred_info in predicates.items():
        one_row = (doc[pred_token].lemma_, 
                   pred_info.get('nsubj', None),
                   pred_info.get('dobj', None)
                  )
        output.append(one_row)
    
    return output

# %%
get_predicate_subject_object(doc)
# Out:
# [('make', 'John', 'cake'), ('get', '-PRON-', None), ('go', '-PRON-', None)]

# %% [markdown]
# ## 2. Aggregating events across text sources

# %% [markdown]
# Using the above function, we can now process text documents and obtain all the events but also subjects and objects as properties. In the next cell, we load one of our text files, process it with spaCy and get the event tuples.

# %%
#### Change the path to your own text file
path_to_file='../lab1-getting-text/techcrunch_search_results/apple%20os%20x17.txt'
events = []
with open(path_to_file) as infile:
    text = infile.read()
    doc = nlp(text)
    events = get_predicate_subject_object(doc)
    print(events)
# Out:
# [('work', 'Sarah', None), ('writer', None, None), ('spend', None, 'year'), ('prior', None, None), ('work', None, None), ('work', 'Sarah', None), ('number', None, None), ('industry', None, None), ('offer', 'late', 'pickup'), ('late', None, None), ('continue', 'war', None), ('make', 'Amazon', None), ('free', 'delivery', None), ('tout', 'Walmart', None), ('offer', 'service', 'booze'), ('announce', 'retailer', 'milestone'), ('wipe', 'bug', None), ('remove', 'sweep', 'rating'), ('sweep', None, None), ('rating', None, None), ('include', None, None), ('brand', None, None), ('free', None, None), ('Ahead', None, None), ('launch', None, None), ('announce', 'company', 'deal'), ('aim', None, None), ('affordable', 'service', None), ('launch', 'Spotify', 'app'), ('app', None, None), ('subscriber', None, 'Oct'), ('announce', 'Spotify', 'launch'), ('boost', None, 'subscription'), ('launch', None, None), ('allow', 'which', None), ('three', 'child', None), ('listen', None, None), ('onli', 'both', None), ('cost', 'Max', '14.99'), ('14.99', None, None), ('announce', None, 'pricing'), ('pricing', None, None), ('along', None, None), ('share', None, 'detail'), ('detail', None, None), ('cost', 'service', '14.99'), ('14.99', None, None), ('establish', 'Walmart', 'accelerator'), ('announce', 'Walmart', 'expansion'), ('expansion', None, None), ('relationship', None, None), ('continue', 'which', None), ('serve', None, None), ('manager', None, None), ('shut', None, 'Vue'), ('shut', 'service', None), ('be', 'service', None), ('as', None, None), ('announce', 'company', None), ('come', 'news', None), ('day', None, None), ('bring', 'Google', 'domain'), ('rest', None, None), ('include', None, None), ('roll', 'Google', None), ('work', 'that', None), ('create', None, 'document'), ('type', '-PRON-', 'doc.new'), ('launch', None, 'program'), ('offering', None, '%'), ('back', None, None), ('Perez', None, None), ('competition', None, None), ('announce', 'Venmo', 'program'), ('allow', 'which', None), ('earn', 'user', 'cash'), ('back', None, None), ('Week', None, None), ('take', 'GameClub', 'Oct'), ('back', None, None), ('Welcome', None, None), ('recap', 'that', 'news'), ('support', '-PRON-', None), ('flow', 'that', None), ('see', 'industry', None), ('industry', None, None), ('bil', '194', None), ('offer', 'GameClub', 'hit'), ('5', None, None), ('introduce', 'Arcade', 'idea'), ('idea', None, None), ('gaming', None, None), ('follow', 'Pass', None), ('subscribe', None, None), ('collection', None, None), ('let', 'ga', None), ('buy', 'artist', "'"), ('promote', None, 'album'), ('add', 'Spotify', 'feature'), ('pop', 'that', 'recommendation'), ('recommendation', None, None), ('think', 'service', None), ('like', '-PRON-', None), ('base', None, None), ('combination', None, None), ('come', 'app', None), ('Ahead', None, None), ('launch', None, None), ('begin', 'app', None), ('roll', None, None), ('platform', None, None), ('raise', 'Current', 'B'), ('top', None, 'user'), ('expand', 'Current', None), ('begin', 'which', None), ('offer', None, 'account'), ('say', 'company', None), ('grow', '-PRON-', None), ('host', None, 'more'), ('more', None, None), ('debut', 'Google', 'be'), ("'", None, None), ('Perez', None, None), ('introduction', None, None), ('tool', None, None), ('expand', 'company', 'feature'), ('include', None, 'option'), ('option', None, None), ('%', None, None), ('adult', None, None), ('%', None, None), ('disapprove', '-PRON-', None), ('create', 'number', 'majority'), ('number', None, None), ('majority', None, None), ('extend', 'that', None), ('discussion', None, None), ('accord', None, None), ('report', None, None), ('sell', 'Quibi', None), ('out', None, None), ('m', None, None), ('launch', 'Quibi', None), ('sell', '’s', None), ('out', None, None), ('announce', 'company', None), ('teach', 'set', 'user'), ('set', None, None), ('focus', '’s', None), ('release', 'TikTok', 'set'), ('set', None, None), ('inform', None, 'user'), ('—', None, None), ('filter', None, 'comment'), ...

# %% [markdown]
# The same event words may occur more than once so let's aggregate them for this file.

# %%
### We define two dictionaries, one for the subjects and one for the objects
event_subjects={}
event_objects={}

### We iterate over the events for a document
for event in events:
    ### we check if the event word (the first element in the tuple: event[0]) 
    ### is in a dictionary or not. If so and if the value is not None, 
    ### we add it to the corresponding dictionaries a subject (event[1])
    if event[0] in event_subjects:
        if event[1]:
            event_subjects[event[0]].append(event[1]) # adding
    ### if the word is not present, we create a new list entry for the word with the value if not None
    elif event[1]:
        event_subjects[event[0]]=[event[1]]  # creating
    ### we repeat the same thing for the object (event[2]) in the object dictionary   
    if event[0] in event_objects:
        if event[2]:
            event_objects[event[0]].append(event[2])
    ### if the word is not present, we create a new list entry for the word with the value if not None
    elif event[2]:
        event_objects[event[0]]=[event[2]]
            
print('Subjects:', event_subjects)
print('Objects:', event_objects)
# Out:
# Subjects: {'work': ['Sarah', 'Sarah', 'that'], 'offer': ['late', 'service', 'GameClub'], 'continue': ['war', 'which'], 'make': ['Amazon'], 'free': ['delivery'], 'tout': ['Walmart'], 'announce': ['retailer', 'company', 'Spotify', 'Walmart', 'company', 'Venmo', 'company', 'company'], 'wipe': ['bug'], 'remove': ['sweep'], 'affordable': ['service'], 'launch': ['Spotify', 'Quibi', 'that'], 'allow': ['which', 'which'], 'three': ['child'], 'onli': ['both'], 'cost': ['Max', 'service'], 'establish': ['Walmart'], 'shut': ['service'], 'be': ['service'], 'come': ['news', 'app'], 'bring': ['Google'], 'roll': ['Google'], 'type': ['-PRON-'], 'earn': ['user'], 'take': ['GameClub'], 'recap': ['that'], 'support': ['-PRON-'], 'flow': ['that'], 'see': ['industry'], 'bil': ['194'], 'introduce': ['Arcade'], 'follow': ['Pass'], 'let': ['ga'], 'buy': ['artist', 'IBM'], 'add': ['Spotify'], 'pop': ['that'], 'think': ['service'], 'like': ['-PRON-'], 'begin': ['app', 'which'], 'raise': ['Current'], 'expand': ['Current', 'company', 'Amazon', 'location'], 'say': ['company'], 'grow': ['-PRON-'], 'debut': ['Google'], 'disapprove': ['-PRON-'], 'create': ['number'], 'extend': ['that'], 'sell': ['Quibi', '’s'], 'teach': ['set'], 'focus': ['’s'], 'release': ['TikTok'], 'reac': ['service'], 'warn': ['Somorjai'], 'dampen': ['politic'], 'rise': ['Carolina'], '’s': ['-PRON-']}
# Objects: {'spend': ['year'], 'offer': ['pickup', 'booze', 'hit', 'account'], 'announce': ['milestone', 'deal', 'launch', 'pricing', 'expansion', 'program'], 'remove': ['rating'], 'launch': ['app', 'program'], 'subscriber': ['Oct'], 'boost': ['subscription'], 'cost': ['14.99', '14.99'], 'share': ['detail'], 'establish': ['accelerator'], 'shut': ['Vue'], 'bring': ['domain'], 'create': ['document', 'majority'], 'type': ['doc.new'], 'offering': ['%'], 'earn': ['cash'], 'take': ['Oct'], 'recap': ['news'], 'introduce': ['idea'], 'buy': ["'", 'Hat'], 'promote': ['album'], 'add': ['feature'], 'pop': ['recommendation'], 'raise': ['B', 'billion'], 'top': ['user'], 'host': ['more'], 'debut': ['be'], 'expand': ['feature', 'service'], 'include': ['option'], 'teach': ['user'], 'release': ['set'], 'inform': ['user'], 'filter': ['comment'], 'dampen': ['potential'], 'Load': ['more']}

# %% [markdown]
# In the next call, we repeat the above for each file in our collection and aggregate the predicates with their subjects and objects in a single subject and object dictionary.

# %%
from pathlib import Path

# The path to the folder with the text files. 
# Here I use a relative path from where I run the notebook
# Adapt the path accordingly to where your data is and/or where you run your notebook
# You can also specify the absolute path

### We define two dictionaries, one for the subjects and one for the objects
event_subjects={}
event_objects={}

basepath = Path('../lab1-getting-text/techcrunch_search_results/')
files_in_basepath = basepath.iterdir()
for path_to_file in files_in_basepath:
    if path_to_file.is_file():  # check of the item is not a subdirectory!!
        print(path_to_file.name)
        with open(path_to_file) as infile:
            text = infile.read()
            doc = nlp(text)
            events = get_predicate_subject_object(doc)
            ### We iterate over the events for a document
            for event in events:
                ### we check if the event word (the first element in the tuple: event[0]) 
                ### is in a dictionary or not. If so and if the value is not None, 
                ### we add it to the corresponding dictionaries a subject (event[1])
                if event[0] in event_subjects:
                    if event[1]:
                        event_subjects[event[0]].append(event[1])
                ### if the word is not present, we create a new list entry for the word with the value if not None
                elif event[1]:
                    event_subjects[event[0]]=[event[1]]
                ### we repeat the same thing for the object (event[2]) in the object dictionary   
                if event[0] in event_objects:
                    if event[2]:
                        event_objects[event[0]].append(event[2])
                ### if the word is not present, we create a new list entry for the word with the value if not None
                elif event[2]:
                    event_objects[event[0]]=[event[2]]
# Out:
# apple%20os%20x17.txt
# apple%20os%20x16.txt
# apple%20os%20x14.txt
# apple%20os%20x9.txt
# apple%20os%20x28.txt
# apple%20os%20x29.txt
# apple%20os%20x8.txt
# apple%20os%20x15.txt
# apple%20os%20x39.txt
# apple%20os%20x11.txt
# apple%20os%20x10.txt
# apple%20os%20x38.txt
# apple%20os%20x12.txt
# apple%20os%20x13.txt
# apple%20os%20x60.txt
# apple%20os%20x48.txt
# apple%20os%20x49.txt
# apple%20os%20x61.txt
# apple%20os%20x59.txt
# apple%20os%20x58.txt
# apple%20os%20x55.txt
# apple%20os%20x41.txt
# apple%20os%20x40.txt
# apple%20os%20x54.txt
# apple%20os%20x42.txt
# apple%20os%20x56.txt
# apple%20os%20x57.txt
# apple%20os%20x43.txt
# apple%20os%20x47.txt
# apple%20os%20x53.txt
# apple%20os%20x52.txt
# apple%20os%20x46.txt
# apple%20os%20x50.txt
# apple%20os%20x44.txt
# apple%20os%20x45.txt
# apple%20os%20x51.txt
# apple%20os%20x36.txt
# apple%20os%20x3.txt
# apple%20os%20x22.txt
# apple%20os%20x23.txt
# apple%20os%20x2.txt
# apple%20os%20x37.txt
# apple%20os%20x21.txt
# apple%20os%20x35.txt
# apple%20os%20x1.txt
# apple%20os%20x34.txt
# apple%20os%20x20.txt
# apple%20os%20x18.txt
# apple%20os%20x24.txt
# apple%20os%20x30.txt
# apple%20os%20x5.txt
# apple%20os%20x4.txt
# apple%20os%20x31.txt
# apple%20os%20x25.txt
# apple%20os%20x19.txt
# apple%20os%20x33.txt
# apple%20os%20x6.txt
# apple%20os%20x27.txt
# apple%20os%20x26.txt
# apple%20os%20x7.txt
# apple%20os%20x32.txt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ff9e8e800f87> in <module>
#      38                     event_objects[event[0]]=[event[2]]
#      39
# ---> 40 print('Subjects:', event_subjectst.items()[0:5])
#      41 print('Objects:', event_objectst.items()[0:5])
#
# NameError: name 'event_subjectst' is not defined

# %%
for key, subjects in event_subjects.items():
    print(key,subjects)
    break

for key, objects in event_objects.items():
    print(key,objects)
    break
# Out:
# work ['Sarah', 'Sarah', 'that', '-PRON-', 'company', '-PRON-', 'Pencil', '-PRON-', 'dongle', '-PRON-', 'that', '-PRON-', '-PRON-', '-PRON-', 'Microsoft', 'Apple', 'company', 'x', 'app', '-PRON-', 'x', 'app', '-PRON-', '-PRON-', 'Pencil', '-PRON-', 'dongle', '-PRON-', 'that', '-PRON-', '-PRON-', '-PRON-', 'Microsoft', 'Apple', '-PRON-', '-PRON-', '-PRON-', '-PRON-', '-PRON-', 'that', '-PRON-', 'that', 'company', 'Siri', '-PRON-', '-PRON-', '-PRON-', 'piece', '-PRON-', 'company', 'piece', 'Siri', '-PRON-', '-PRON-', '-PRON-', 'company', 'company']
# spend ['year', 'couple', 'couple', 'thousand', 'couple', 'couple', 'couple', 'couple']

# %% [markdown]
# ## 3 counting subjects and objects for events

# %% [markdown]
# We see there is a lot of repetition. We would like to keep the unique subjects and objects but count them. For this we use the *Counter* package to count the elements in a list and derive a new dictionary with the counts.

# %%
from collections import Counter 

event_counted_subjects={}
event_counted_objects={}

for key, subjects in event_subjects.items():
    event_counted_subjects[key]=Counter(subjects)

for key, objects in event_objects.items():
    event_counted_objects[key]=Counter(objects)

for key, subjects in event_counted_subjects.items():
    print(key, subjects)

for key, objects in event_counted_objects.items():
    print(key, objects)

   
#print('Counted subjects:', event_counted_subjects)
#print('Counted objects:', event_counted_objects)
# Out:
# work Counter({'-PRON-': 28, 'company': 6, 'that': 5, 'Sarah': 2, 'Pencil': 2, 'dongle': 2, 'Microsoft': 2, 'Apple': 2, 'x': 2, 'app': 2, 'Siri': 2, 'piece': 2})
# offer Counter({'-PRON-': 6, 'procreate': 2, 'Pencil': 2, 'party': 2, 'Pro': 2, 'message': 2, 'late': 1, 'service': 1, 'GameClub': 1, 'which': 1, 'world': 1})
# continue Counter({'trickle': 2, 'app': 2, 'war': 1, 'which': 1, 'crisis': 1, 'death': 1, 'robot': 1})
# make Counter({'-PRON-': 22, 'that': 14, 'which': 6, 'app': 4, 'feature': 4, 'what': 3, 'Apple': 2, 'contact': 2, 'company': 2, 'patch': 2, 'move': 2, 'assistant': 2, 'feedback': 2, 'Capitan': 2, 'website': 2, 'Amazon': 1, 'Arcade': 1, 'people': 1, 'all': 1, 'sale': 1})
# free Counter({'delivery': 1})
# tout Counter({'Walmart': 1})
# announce Counter({'company': 25, 'Apple': 18, '’s': 6, 'Google': 5, 'Federighi': 2, 'retailer': 1, 'Spotify': 1, 'Walmart': 1, 'Venmo': 1, 'date': 1, 'PayPal': 1, 'Department': 1, 'Mozilla': 1, 'McDermott': 1, 'Canva': 1, 'BoxGroup': 1, 'Dorsey': 1, 'outfitter': 1, 'CDC': 1})
# wipe Counter({'bug': 1})
# remove Counter({'Apple': 2, 'sweep': 1})
# affordable Counter({'service': 1})
# launch Counter({'-PRON-': 11, 'Tesla': 10, 'Apple': 9, 'Oct': 6, 'which': 3, 'Music': 2, 'Pencil': 2, 'Thync': 2, 'Kamcord': 2, 'Stadia': 2, 'Spotify': 1, 'Quibi': 1, 'that': 1, 'Surface': 1, 'Asana': 1, 'Zoho': 1, 'Microsoft': 1, 'Canva': 1, 'B': 1})
# allow Counter({'that': 8, 'which': 4, 'panel': 2, 'array': 2, 'addition': 2, 'Apple': 2})
# three Counter({'child': 1})
# onli Counter({'both': 1})
# cost Counter({'Roof': 5, 'Max': 1, 'service': 1})
# establish Counter({'Walmart': 1})
# shut Counter({'service': 1})
# be Counter({'-PRON-': 170, 'this': 23, 'that': 22, 'Apple': 14, '’s': 14, 'Capitan': 12, 'Pro': 11, 'system': 11, 'change': 8, 'advantage': 8, 'x': 8, 'feature': 8, 'which': 8, 'one': 7, 'Dillet': 6, 'Addresses': 6, 'Shadow': 6, 'startup': 6, 'Cowboy': 6, 'community': 6, 'Foundation': 6, 'Cityscoot': 6, 'Google': 6, 'Pixel': 6, 'process': 6, 'who': 6, 'Pencil': 6, 'thing': 6, 'Control': 6, 'Francisco': 6, 'these': 5, 'news': 5, 'camera': 5, 'Microsoft': 5, 'Etherington': 5, 'technology': 5, 'up': 5, 'week': 5, 'hope': 5, 'propulsion': 5, 'what': 4, 'ability': 4, 'grip': 4, 'effect': 4, 'app': 4, 'Metal': 4, 'majority': 4, 'Majority': 4, 'software': 4, 'connection': 3, 'company': 3, 'iPhone': 3, 'Crook': 3, 'addition': 2, 'update': 2, 'gesture': 2, 'color': 2, 'many': 2, 'band': 2, 'model': 2, 'coil': 2, 'edge': 2, 'plenty': 2, 'Grip': 2, 'downside': 2, 'touch': 2, 'reach': 2, 'speaker': 2, 'rhetoric': 2, 'platform': 2, 'monitor': 2, 'port': 2, 'speed': 2, 'answer': 2, 'performance': 2, 'transition': 2, 'drawing': 2, 'era': 2, 'side': 2, 'time': 2, 'screen': 2, 'way': 2, 'Folio': 2, 'editing': 2, 'keyboard': 2, 'design': 2, 'Keyboard': 2, 'wish': 2, 'fact': 2, 'aesthetic': 2, 'technique': 2, 'promotion': 2, 'rendition': 2, 'summary': 2, 'base': 2, 'stylus': 2, 'Russell': 2, 'keynote': 2, 'Electroloom': 2, 'fan': 2, 'gadget': 2, 'focus': 2, 'release': 2, 'pace': 2, 'X': 2, 'chance': 2, 'protection': 2, 'bar': 2, 'section': 2, 'Notes': 2, 'part': 2, 'exit': 2, 'Kumparak': 2, 'link': 2, 'most': 2, 'animation': 2, 'October': 2, '21': 2, 'Air': 2, 'launch': 2, 'event': 2, 'all': 2, 'assistant': 2, 'Siri': 2, 'new': 2, '’': 2, "'": 2, 'thinking': 2, 'population': 2, 'scrutiny': 2, 'stake': 2, 'Machine': 2, 'Sierra': 2, 'version': 2, 'theory': 2, 'album': 2, 'Safari': 2, 'video': 2, 'macos': 2, 'Mac': 2, 'SiriKit': 2, 'user': 2, 'beta': 2, 'reality': 2, 'issue': 2, 'watchOS': 2, 'service': 1, 'Panzarino': 1, 'audio': 1, 'Mode': 1, 'moment': 1, 'Hack': 1, 'trailer': 1, 'NTWRK': 1, 'Greg': 1, 'network': 1, 'Stadia': 1, 'game': 1, 'house': 1, 'home': 1, 'Chances': 1, 'IPOs': 1, 'Zoho': 1, 'Berlin': 1, 'round': 1, 'Politician': 1, 'film': 1, 'House': 1, 'TechCrunch': 1, 'website': 1, 'late': 1, 'timing': 1, 'reflex': 1, 'death': 1, 'computing': 1, 'truth': 1, 'AI': 1, 'FrankOne': 1, 'maker': 1, 'debris': 1, 'Labs': 1, 'spacesuit': 1, 'Matney': 1, 'consumerization': 1, 'California': 1, 'crisis': 1, 'Spiegel': 1, 'Foursquare': 1})
# come Counter({'-PRON-': 16, 'Drake': 6, 'that': 4, 'power': 2, 'Lynch': 2, 'feature': 2, 'update': 2, 'all': 2, 'support': 2, 'news': 1, 'app': 1, 'word': 1, 'Braun': 1, 'what': 1})
# bring Counter({'-PRON-': 5, 'Google': 2, 'Capitan': 2, 'update': 2, 'that': 2, 'version': 2, 'which': 2, 'https://techcrunch.com/2015/03/02/apple-brings-photos-app-to-the-os-x-public-beta-program/': 2, 'Databricks': 1, 'Photonics': 1})
# roll Counter({'update': 4, 'Apple': 4, 'which': 4, 'ios': 2, '-PRON-': 2, 'Maps': 2, 'Google': 1, 'late': 1})
# type Counter({'-PRON-': 1})
# earn Counter({'user': 1})
# take Counter({'-PRON-': 15, '’s': 6, 'Federighi': 4, 'Apple': 2, 'Maps': 2, 'that': 2, 'GameClub': 1, 'company': 1, 'Google': 1})
# recap Counter({'Congress': 5, 'that': 1})
# support Counter({'Pro': 2, 'change': 2, 'website': 2, 'photo': 2, '-PRON-': 1})
# flow Counter({'that': 1})
# see Counter({'-PRON-': 24, 'vehicle': 5, 'industry': 1})
# bil Counter({'194': 1})
# introduce Counter({'Apple': 6, '9.1': 2, 'Arcade': 1, 'Accelerator': 1})
# follow Counter({'X': 4, 'Pass': 1})
# let Counter({'that': 14, 'Cowboy': 6, 'which': 2, '-PRON-': 2, 'ga': 1, 'Panzarino': 1, 'Steam': 1, 'Community': 1})
# buy Counter({'artist': 1, 'IBM': 1, '-PRON-': 1, 'Apple': 1})
# add Counter({'Apple': 16, '-PRON-': 10, 'user': 2, 'Spotify': 1, 'Axon': 1})
# pop Counter({'be': 2, 'case': 2, '-PRON-': 2, 'that': 1})
# think Counter({'-PRON-': 21, 'market': 5, 'service': 1})
# like Counter({'-PRON-': 12})
# begin Counter({'sale': 5, 'which': 3, 'proportion': 2, 'Apple': 2, 'Federighi': 2, 'app': 1, 'Google': 1})
# raise Counter({'MadBox': 12, 'Strapi': 12, 'Polte': 12, '-PRON-': 3, 'HomeSuite': 2, 'founder': 2, 'PicsArt': 2, 'Koio': 2, 'havenly': 2, 'Current': 1, 'Rune': 1, 'Cloosiv': 1, 'Autify': 1, 'Nexkey': 1, 'late': 1, 'BoxGroup': 1, 'which': 1, 'Choco': 1, 'Taskade': 1, 'VR': 1})
# expand Counter({'company': 6, 'Revolut': 6, 'Waymo': 5, 'x': 2, 'Current': 1, 'Amazon': 1, 'location': 1, 'Adobe': 1, 'Scholar': 1})
# say Counter({'Apple': 20, 'Musk': 10, '-PRON-': 6, 'company': 2, 'that': 2, 'Singleton': 2, 'Dot': 2, '9to5mac': 2, 'page': 2, 'Reuters': 1, 'Google': 1})
# grow Counter({'-PRON-': 1, 'designer': 1, 'Nadeshot': 1})
# debut Counter({'Tesla': 5, '-PRON-': 2, 'which': 2, 'Google': 1, 'Dropbox': 1})
# disapprove Counter({'-PRON-': 1})
# create Counter({'Printer': 2, 'number': 1})
# extend Counter({'that': 1})
# sell Counter({'darle': 2, 'Apple': 2, 'Quibi': 1, '’s': 1, '-PRON-': 1})
# teach Counter({'set': 1})
# focus Counter({'company': 7, 'startup': 2, 'Apple': 2, '-PRON-': 2, '’s': 1, 'which': 1, 'that': 1})
# release Counter({'Apple': 26, 'Todoist': 6, 'company': 6, 'TikTok': 1})
# reac Counter({'service': 1})
# warn Counter({'Somorjai': 1})
# dampen Counter({'politic': 1})
# rise Counter({'which': 2, 'Carolina': 1, 'number': 1})
# ’s Counter({'-PRON-': 75, 'that': 40, 'what': 2, 'loop': 2, 'Netflix': 1})
# iOS Counter({'Updates': 4})
# @sarahintampa Counter({'Perez': 2})
# receive Counter({'both': 2, 'user': 2, '-PRON-': 2, 'Control': 2, 'message': 2, 'Yosemite': 2})
# move Counter({'-PRON-': 6, 'Apple': 2, 'Pencil': 2, 'NTWRK': 1})
# note Counter({'Emojipedia': 2, 'company': 2})
# include Counter({'-PRON-': 3, 'standard': 2, 'OS': 2, '10.11.1': 2, 'Apple': 2, 'feature': 2, 'which': 2, 'beta': 2})
# animate Counter({'that': 2})
# sense Counter({'iPhone': 2})
# record Counter({'-PRON-': 6, 'Pro': 2})
# play Counter({'-PRON-': 3, '’s': 2, 'be': 1})
# have Counter({'-PRON-': 56, 'company': 12, 'Apple': 10, 'Revolut': 6, 'startup': 5, 'Nvidia': 5, 'rover': 5, 'that': 4, 'developer': 2, 'action': 2, 'many': 2, 'Pencil': 2, 'user': 2, 'rhetoric': 2, 'version': 2, 'model': 2, 'camera': 2, 'iPad': 2, 'cycle': 2, 'mail': 2, 'Bash': 2, 'Opera': 2, 'site': 2, 'other': 2, 'wearable': 2, 'game': 1, 'enterprise': 1, 'technique': 1, 'world': 1, 'system': 1, 'investigation': 1, 'day': 1, 'nothing': 1, 'Google': 1})
# update Counter({'Google': 6, 'Apple': 3, 'credit': 2, 'article': 2, '-PRON-': 1})
# indicate Counter({'chart': 2})
# syncing Counter({'event': 2})
# cause Counter({'that': 2})
# available Counter({'update': 2, 'file': 2, 'download': 2})
# should Counter({'-PRON-': 2})
# download Counter({'-PRON-': 2, 'those': 2})
# serve Counter({'port': 2, '-PRON-': 1, 'which': 1})
# ship Counter({'Apple': 4, 'Pro': 2, '-PRON-': 2, 'which': 2, 'beta': 1})
# do Counter({'-PRON-': 9, 'Apple': 8, 'iPad': 4, 'Pencil': 2, 'work': 2, 'everyone': 2, 'people': 2, 'Sierra': 2, 'iPhone': 1, 'Coldewey': 1, 'Americans': 1})
# get Counter({'-PRON-': 14, 'Safari': 4, '’s': 4, 'app': 3, 'any': 2, 'photography': 2, 'be': 2, 'slowdown': 2, 'spotlight': 2, 'X': 2, 'which': 2, 'Card': 1, 'amount': 1, 'effect': 1, 'Superhuman': 1, 'batch': 1, 'SiriusXM': 1, "'": 1, 'Bone': 1, 'homeowner': 1, 'company': 1, 'Firefox': 1, 'Swarm': 1, 'that': 1, 'SDK': 1})
# compare Counter({'-PRON-': 1})
# hope Counter({'-PRON-': 7})
# seem Counter({'-PRON-': 4, 'notion': 2, 'everything': 2, 'this': 2, 'icon': 2, 'x': 2, 'Arcade': 1})
# change Counter({'-PRON-': 3, 'cursor': 2, 'access': 2, 'Panzarino': 1, 'economy': 1})
# comply Counter({'app': 1})
# unveil Counter({'Google': 6, 'late': 5, 'Apple': 2, 'mini': 2, 'company': 1})
# read Counter({'-PRON-': 2})
# turn Counter({'Nobody': 2, '-PRON-': 2, 'Apple': 1, 'James': 1})
# Siri Counter({'that': 1})
# sign Counter({'that': 1})
# suspend Counter({'Apple': 1})
# review Counter({'-PRON-': 2})
# go Counter({'-PRON-': 11, '’s': 10, 'SE': 5, 'Apple': 4, 'that': 3, 'Pro': 2, 'this': 2, 'what': 2, 'company': 2, 'developer': 2, 'editor': 1, 'app': 1, 'all': 1, 'grant': 1})
# tend Counter({'app': 1, 'company': 1, 'area': 1})
# cut Counter({'that': 1})
# disable Counter({'Apple': 2, '-PRON-': 2})
# eavesdropping Counter({'iPhone': 1})
# listen Counter({'person': 1})
# tell Counter({'-PRON-': 3, 'company': 1})
# notice Counter({'-PRON-': 8, 'someone': 1})
# use Counter({'-PRON-': 39, 'Apple': 10, 'company': 8, 'Darrell': 5, 'be': 2, 'generation': 2, 'device': 2, 'Safari': 2, 'X': 2, 'Users': 2, 'startup': 1, 'anything': 1, 'CampusReel': 1, 'Scholar': 1})
# leave Counter({'Jony': 1, '—': 1})
# require Counter({'-PRON-': 2, 'which': 2, 'that': 2, 'app': 2, 'Capitan': 2, 'Apple': 1})
# keynote Counter({'’s': 1})
# prove Counter({'program': 2, 'this': 2, '-PRON-': 1, 'what': 1})
# kick Counter({'Musk': 5, 'Conference': 1, '-PRON-': 1})
# i Counter({'rest': 1})
# fly Counter({'Pencil': 2, '-PRON-': 1})
# mean Counter({'which': 4, 'this': 2, 'power': 2, 'that': 2, '-PRON-': 2, 'graduation': 2, 'boost': 1})
# invite Counter({'that': 2, 'Apple': 1})
# center Counter({'which': 1})
# fix Counter({'10.11.3': 2, 'release': 2, 'ios': 2, 'handling': 2})
# expect Counter({'-PRON-': 6, 'user': 2, 'would': 2, 'CEO': 1})
# photo Counter({'life': 2})
# eliminate Counter({'Shift': 2})
# ’ Counter({'-PRON-': 33})
# confusing Counter({'-PRON-': 2})
# die Counter({'iPhone': 2})
# watch Counter({'-PRON-': 8, 'Watch': 2})
# attend Counter({'Romain': 6})
# cover Counter({'-PRON-': 8, 'that': 2, 'Frederic': 1})
# speak Counter({'-PRON-': 7, 'Eldon': 1})
# live Counter({'-PRON-': 7})
# own Counter({'-PRON-': 7, 'wife': 2})
# want Counter({'-PRON-': 16, 'that': 7, 'what3word': 6, 'Uber': 6, 'Apple': 6, 'people': 5, '’s': 5, 'Adams': 2, 'People': 2, 'Avalow': 1, 'customer': 1})
# feature Counter({'update': 6, 'top': 2, 'Gmail': 2, 'map': 1})
# issue Counter({'Apple': 8, 'company': 6})
# suggest Counter({'name': 6, 'mail': 2, 'week': 2})
# easy Counter({'recruitment': 6})
# deal Counter({'sign': 6})
# spend Counter({'-PRON-': 6})
# Bootstrapped Counter({'Dillet': 6})
# pay Counter({'-PRON-': 12})
# cave Counter({'Apple': 6})
# develop Counter({'company': 6, '-PRON-': 2})
# build Counter({'that': 8, 'Kabuto': 6, 'company': 6, 'extension': 5, 'Apple': 2, '-PRON-': 1})
# overhauls Counter({'Google': 6})
# hav Counter({'-PRON-': 6})
# know Counter({'-PRON-': 16, 'Safari': 2})
# track Counter({'Foodvisor': 6, 'individual': 1})
# eat Counter({'-PRON-': 12})
# help Counter({'that': 6, 'startup': 5, '-PRON-': 2, 'pool': 2, 'AI': 1})
# log Counter({'-PRON-': 6})
# leverage Counter({'that': 6, 'preview': 2})
# become Counter({'Klarna': 6, '-PRON-': 5, 'Galactic': 5, 'Watch': 2, 'Mac': 2, 'OS': 2, 'that': 1, 'feature': 1})
# excite Counter({'’s': 6, 'that': 2, 'investor': 1})
# show Counter({'app': 4, 'tablet': 2, 'that': 2, 'level': 2, 'announcement': 2, 'Maps': 2, 'model': 2, 'Federighi': 2})
# believe Counter({'-PRON-': 12, 'Apple': 2})
# start Counter({'Apple': 4, 'thing': 2, 'would': 2, '’s': 2, '-PRON-': 2, 'convention': 2, 'Greg': 1, 'Dropbox': 1, 'app': 1})
# open Counter({'-PRON-': 6, 'hardware': 2, 'company': 2, 'user': 2})
# handle Counter({'that': 2})
# feel Counter({'-PRON-': 21, 'gesture': 2, 'that': 2, 'device': 2, 'one': 2, 'Pencil': 2, 'software': 2})
# toggle Counter({'-PRON-': 2})
# enable Counter({'what': 2, 'this': 2})
# adjust Counter({'-PRON-': 2})
# swap Counter({'-PRON-': 2})
# tap Counter({'-PRON-': 4})
# isolate Counter({'’s': 2})
# love Counter({'-PRON-': 2})
# give Counter({'-PRON-': 4, 'Apple': 2, 'user': 2, 'this': 2})
# reflect Counter({'that': 2})
# instruct Counter({'guideline': 2})
# encourage Counter({'-PRON-': 2})
# look Counter({'-PRON-': 16, 'SpaceX': 5, 'implementation': 2, 'item': 2, 'conversation': 2, 'Apple': 2, 'everybody': 2, 'that': 2, 'chip': 1, 'Alphabet': 1, 'Rhino': 1, 'NASA': 1})
# — Counter({'pair': 2, '-PRON-': 2, 'Pro': 2})
# pair Counter({'-PRON-': 4, 'Pencil': 2})
# happen Counter({'that': 4, 'pairing': 2, '-PRON-': 2, 'nothing': 2, '’s': 1})
# charge Counter({'-PRON-': 2})
# pull Counter({'Apple': 2, '-PRON-': 2, 'Games': 1})
# hold Counter({'-PRON-': 7, 'that': 4, 'Apple': 2, 'precedent': 2, 'Google': 1, 'Accelerator': 1})
# sketch Counter({'who': 2})
# snap Counter({'-PRON-': 2})
# provide Counter({'-PRON-': 6, 'Pencil': 2, 'port': 2, 'Maps': 2, 'spokesperson': 2, 'x': 2, 'that': 1, '’': 1})
# happy Counter({'artist': 2})
# scratch Counter({'-PRON-': 2})
# enhance Counter({'that': 2})
# blow Counter({'that': 2})
# choose Counter({'-PRON-': 3})
# link Counter({'’s': 2})
# manipulate Counter({'-PRON-': 2})
# draw Counter({'be': 2, 'iOS': 2})
# ground Counter({'-PRON-': 2})
# solve Counter({'Pencil': 2, 'robot': 1})
# deliver Counter({'Apple': 2, 'system': 2, 'release': 2})
# talk Counter({'-PRON-': 6, '’s': 2, 'someone': 2})
# concede Counter({'Apple': 2})
# run Counter({'-PRON-': 6, 'laptop': 2, 'be': 2, 'TV': 2, 'Watch': 2})
# trickle Counter({'this': 2})
# stem Counter({'-PRON-': 2, 'X': 2})
# benefit Counter({'that': 2})
# connect Counter({'that': 2})
# plug Counter({'-PRON-': 2})
# fit Counter({'one': 2})
# need Counter({'-PRON-': 21, 'Apple': 2, 'user': 2})
# affect Counter({'that': 2, 'which': 2})
# encounter Counter({'-PRON-': 2})
# edit Counter({'who': 2})
# integrate Counter({'-PRON-': 2, 'Games': 2})
# crystallize Counter({'result': 2})
# end Counter({'-PRON-': 2})
# hear Counter({'-PRON-': 21, 'TechCrunch': 4})
# stick Counter({'-PRON-': 2})
# decide Counter({'team': 2, '-PRON-': 1, 'Facebook': 1})
# smaller Counter({'sensor': 2})
# remain Counter({'fact': 4, 'that': 2, 'iPad': 2, 'stock': 1})
# unlock Counter({'-PRON-': 4})
# write Counter({'-PRON-': 6})
# demand Counter({'work': 2})
# arrange Counter({'set': 2})
# slap Counter({'-PRON-': 2})
# find Counter({'-PRON-': 8, 'Galactic': 5, 'who': 2})
# appear Counter({'-PRON-': 2, 'improvement': 2, 'that': 1})
# curve Counter({'matching': 2})
# fall Counter({'edge': 2, 'car': 2})
# mate Counter({'-PRON-': 2})
# bump Counter({'camera': 2})
# wobble Counter({'iPad': 2})
# lay Counter({'-PRON-': 2})
# fine Counter({'-PRON-': 2})
# holdable Counter({'-PRON-': 2})
# manage Counter({'iPads': 2})
# debate Counter({'-PRON-': 2})
# hard Counter({'-PRON-': 2})
# gain Counter({'screen': 2, 'user': 2})
# exhibit Counter({'-PRON-': 2})
# darken Counter({'-PRON-': 2})
# tablet Counter({'-PRON-': 2})
# stop Counter({'anyone': 2, 'that': 2})
# discussion Counter({'’s': 2})
# toaster Counter({'refrigerator': 2})
# stand Counter({'Pencil': 2, 'Capitan': 2})
# mouse Counter({'Pencil': 2})
# blend Counter({'that': 2})
# detach Counter({'-PRON-': 2})
# advanced Counter({'"': 2})
# report Counter({'-PRON-': 2, 'Bloomberg': 2, 'which': 2, 'MacRumors': 2, 'privacy': 1, 'state': 1, 'Verge': 1})
# fight Counter({'Yahoo': 2})
# adapt Counter({'company': 2, 'maker': 1})
# gather Counter({'Russell': 2})
# Kyle Counter({'Gaming': 2})
# sit Counter({'company': 2, 'Siri': 2, 'editor': 1, '-PRON-': 1})
# steal Counter({'force': 2})
# test Counter({'dna': 2, '-PRON-': 2})
# Keynote Counter({'’s': 2})
# sum Counter({'-PRON-': 2})
# discuss Counter({'-PRON-': 2})
# diversify Counter({'-PRON-': 2})
# share Counter({'-PRON-': 3, 'user': 2})
# Found Counter({'Path': 2})
# what Counter({'car': 2})
# lose Counter({'-PRON-': 4})
# put Counter({'Wear': 2, 'Apple': 2})
# demonstrate Counter({'Google': 3})
# remember Counter({'-PRON-': 3, 'user': 2})
# disappear Counter({'problem': 2})
# confirm Counter({'president': 5, 'release': 2, '-PRON-': 1})
# list Counter({'Apple': 2})
# offload Counter({'-PRON-': 2})
# alter Counter({'app': 2})
# may Counter({'that': 2})
# switch Counter({'Apple': 2, 'user': 2})
# stack Counter({'x': 2})
# drag Counter({'-PRON-': 2})
# divide Counter({'-PRON-': 2})
# resize Counter({'-PRON-': 2})
# search Counter({'-PRON-': 6})
# understand Counter({'keyboard': 4, 'spotlight': 2})
# stable Counter({'x': 4, 'macos': 2})
# pin Counter({'-PRON-': 2})
# mute Counter({'-PRON-': 2})
# draft Counter({'-PRON-': 2})
# swipe Counter({'-PRON-': 2, 'recipient': 2})
# miss Counter({'user': 2})
# plan Counter({'-PRON-': 2})
# select Counter({'-PRON-': 2})
# rely Counter({'many': 2, 'user': 1, 'robot': 1, 'that': 1})
# prompt Counter({'manufacturing': 5, 'hackery': 2})
# ask Counter({'-PRON-': 7, 'friend': 2, 'someone': 2, 'Coldewey': 1})
# best Counter({'system': 5})
# proceed Counter({'company': 5})
# price Counter({'SE': 5})
# return Counter({'X-37B': 5, 'Jedi': 1, 'Fortnite': 1})
# launc Counter({'-PRON-': 5})
# win Counter({'tv': 5, 'Microsoft': 2, '-PRON-': 1})
# replace Counter({'TV': 5, 'Siri': 2})
# complete Counter({'which': 6})
# detail Counter({'-PRON-': 5})
# rest Counter({'rover': 5})
# Oct Counter({'’s': 5, 'CEO': 1})
# SpaceX Counter({'Astrovan': 5})
# shed Counter({'speak': 5})
# intend Counter({'SpaceX': 5, 'Apple': 2})
# Was Counter({'office': 5})
# explain Counter({'Bridenstine': 5})
# convene Counter({'industry': 5})
# arrive Counter({'driving': 5, 'company': 5, '-PRON-': 2, 'update': 2})
# lead Counter({'-PRON-': 1, 'Jordan': 1})
# acquire Counter({'AOL': 1, 'atlassian': 1, '-PRON-': 1, 'Apple': 1})
# merge Counter({'site': 1})
# break Counter({'Kumparak': 1, 'name': 1, '-PRON-': 1})
# smartphone Counter({'detail': 1})
# call Counter({'Apple': 4, '-PRON-': 1})
# series Counter({'who': 1})
# pick Counter({'Capitan': 2, 'Latest': 1, 'division': 1})
# tear Counter({'-PRON-': 1})
# keep Counter({'entrepreneur': 1})
# learn Counter({'-PRON-': 1})
# drop Counter({'Apple': 2, 'Google': 1, 'EBay': 1})
# try Counter({'-PRON-': 7, 'eye': 2, 'sense': 2, 'Safari': 2, 'that': 1})
# evaluate Counter({'company': 1})
# publish Counter({'Combinator': 1})
# compete Counter({'that': 1})
# reinvent Counter({'Dropbox': 1})
# refocus Counter({'company': 1})
# host Counter({'balloon': 1})
# load Counter({'-PRON-': 3, 'slot': 2, 'page': 2, 'CrashSafari': 2})
# tinker Counter({'’d': 2})
# push Counter({'-PRON-': 2})
# grab Counter({'be': 2, 'Messages': 2})
# suppose Counter({'-PRON-': 2})
# shell Counter({'Unix': 2})
# configure Counter({'user': 2, '-PRON-': 2})
# join Counter({'devs': 4, '-PRON-': 1})
# swing Counter({'Apple': 2})
# range Counter({'this': 2})
# send Counter({'-PRON-': 4, 'user': 2, 'team': 1})
# spot Counter({'user': 2})
# hide Counter({'that': 2})
# tip Counter({'iPad': 4})
# gear Counter({'-PRON-': 2})
# echo Counter({'AppleInsider': 2})
# peg Counter({'analyst': 2})
# differentiate Counter({'Apple': 2})
# represent Counter({'system': 2, '-PRON-': 1})
# head Counter({'Apple': 2})
# perform Counter({'-PRON-': 2})
# sync Counter({'Apple': 2, 'iCloud': 2})
# equal Counter({'Apple': 2})
# wish Counter({'-PRON-': 2})
# reveal Counter({'impression': 2})
# tackle Counter({'-PRON-': 2, 'Apple': 2})
# found Counter({'-PRON-': 1})
# ramp Counter({'late': 1})
# mark Counter({'Go': 1})
# seek Counter({'-PRON-': 1, 'which': 1})
# step Counter({'McDermott': 1})
# smart Counter({'door': 1})
# recognize Counter({'-PRON-': 1})
# email Counter({'-PRON-': 1})
# shrink Counter({'that': 1, '-PRON-': 1})
# bonker Counter({"'": 1})
# agree Counter({'-PRON-': 1})
# Watch Counter({'SF': 1})
# descend Counter({'Disrupt': 1})
# assume Counter({'some': 1})
# produce Counter({'ERA': 1})
# Si Counter({'Lauren': 1})
# ha Counter({'Anthony': 1})
# consider Counter({'Apple': 2})
# pursue Counter({'-PRON-': 2})
# differ Counter({'which': 2})
# resemble Counter({'who': 2})
# present Counter({'x': 2})
# outweigh Counter({'benefit': 2})
# account Counter({'which': 2})
# shift Counter({'strategy': 2})
# pack Counter({'update': 2})
# upgrade Counter({'this': 2})
# name Counter({'Apple': 2})
# sound Counter({'-PRON-': 2, 'this': 2, 'name': 2})
# set Counter({'-PRON-': 2})
# delete Counter({'-PRON-': 2})
# bake Counter({'Apple': 2})
# compile Counter({'memory': 2})
# tab Counter({'Safari': 2})
# behave Counter({'tab': 2})
# display Counter({'message': 2})
# mention Counter({'-PRON-': 2, 'file': 2})
# install Counter({'-PRON-': 2})
# copy Counter({'-PRON-': 2})
# optimize Counter({'-PRON-': 2})
# implement Counter({'Apple': 2})
# port Counter({'Apple': 2})
# video Counter({'sense': 2})
# revolutionize Counter({'Sierra': 2})
# new Counter({'’s': 2})
# excited Counter({'-PRON-': 2})
# patch Counter({'Apple': 4})
# wrap Counter({'this': 2})
# inoculate Counter({'-PRON-': 2})
# ignore Counter({'-PRON-': 2})
# parse Counter({'-PRON-': 2})
# surprise Counter({'Federighi': 2})
# claim Counter({'Apple': 2})
# beta Counter({'developer': 2, 'ios9': 2})
# disallow Counter({'platform': 1})
# enter Counter({'-PRON-': 1})
# Devin Counter({'something': 1})
# inspire Counter({'eye': 1})
# computing Counter({'Quantum': 1})
# exist Counter({'compute': 1})
# would Counter({'-PRON-': 1})
# hunt Counter({'rover': 1})
# can Counter({'-PRON-': 1})
# rele Counter({'board': 1})
# scoff Counter({'Everyone': 1})
# restore Counter({'scholar': 1})
# aim Counter({'Technologies': 1, 'startup': 1})
# funky Counter({'one': 1})
# amount Counter({'solution': 1})
# point Counter({'sign': 2})
# hint Counter({'SVP': 2})
# describe Counter({'MacOS': 2})
# rebrande Counter({'Apple': 2})
# crash Counter({'that': 8, 'iPhone': 2})
# close Counter({'-PRON-': 2})
# click Counter({'-PRON-': 2})
# participate Counter({'who': 2})
# borrow Counter({'that': 2})
# experience Counter({'change': 2})
# beat Counter({'Apple': 1})
# govern Counter({'Facebook': 1})
# stretch Counter({'that': 1})
# hit Counter({'Switch': 1})
# surpass Counter({'sale': 1})
# succeed Counter({'service': 1})
# approve Counter({'FCC': 1, 'Commission': 1})
# reach Counter({'-PRON-': 1})
# blindfold Counter({'-PRON-': 1})
# thrust Counter({'announcement': 1})
# spend Counter({'couple': 6, 'year': 1, 'thousand': 1})
# offer Counter({'service': 5, 'behavior': 2, 'bunch': 2, 'upgrade': 2, 'HDR': 2, 'incline': 2, 'case': 2, 'experience': 2, 'flexibility': 2, 'emojification': 2, 'program': 2, 'group': 2, 'pickup': 1, 'booze': 1, 'hit': 1, 'account': 1, 'sign': 1, 'product': 1, 'those': 1, 'opportunity': 1})
# announce Counter({'device': 12, 'plan': 7, 'news': 6, 'integration': 6, 'update': 6, 'that': 6, 'iteration': 4, 'launch': 3, 'close': 3, 'upgrade': 2, 'milestone': 1, 'deal': 1, 'pricing': 1, 'expansion': 1, 'program': 1, 'Pros': 1, 'one': 1, 'project': 1, 'agenda': 1, '—': 1})
# remove Counter({'Maps': 2, 'rating': 1, '-PRON-': 1})
# launch Counter({'campaign': 6, 'iteration': 5, 'service': 5, 'version': 5, 'Apps': 4, 'app': 3, '30th': 2, 'model': 2, 'headset': 2, 'Control': 2, 'Air': 2, 'iPad': 2, 'product': 2, 'update': 2, 'software': 2, 'program': 1, 'feature': 1, 'look': 1, 'sort': 1, 'Enterprise': 1, 'Asana': 1, 'Catalyst': 1, 'project': 1, '649': 1})
# subscriber Counter({'Oct': 1})
# boost Counter({'energy': 2, 'subscription': 1})
# cost Counter({'less': 5, '14.99': 2})
# share Counter({'iPad': 2, 'clip': 2, 'vulnerability': 2, 'detail': 1, 'insight': 1})
# establish Counter({'accelerator': 1})
# shut Counter({'Vue': 1})
# bring Counter({'-PRON-': 5, 'snow': 4, 'screen': 2, 'fix': 2, 'Continuity': 2, 'call': 2, 'order': 2, 'support': 2, 'Siri': 2, 'project': 2, 'that': 2, 'gain': 2, 'Games': 2, 'look': 2, 'app': 2, 'domain': 1, 'ordering': 1, 'AI': 1, 'funding': 1, 'valuation': 1, 'lidar': 1, 'ingredient': 1})
# create Counter({'space': 2, 'garment': 2, 'clothing': 2, 'View': 2, 'address': 2, 'document': 1, 'majority': 1, 'people': 1, 'supergroup': 1, 'brand': 1})
# type Counter({'doc.new': 1})
# offering Counter({'%': 1})
# earn Counter({'cash': 1})
# take Counter({'step': 4, 'look': 3, 'responsibility': 2, 'many': 2, 'that': 2, 'Extravaganza': 2, 'day': 2, 'most': 2, 'space': 2, '-PRON-': 2, 'minute': 2, 'year': 2, 'stage': 2, 'Oct': 1, 'work': 1, 'funding': 1, 'some': 1, 'amp': 1, 'action': 1, 'Notion': 1})
# recap Counter({'Oct': 5, 'news': 1})
# introduce Counter({'feature': 4, 'number': 2, 'update': 2, 'idea': 1, 'startup': 1})
# buy Counter({'-PRON-': 3, "'": 1, 'Hat': 1, 'studio': 1})
# promote Counter({'album': 1})
# add Counter({'handful': 6, 'datum': 6, 'support': 6, 'feature': 5, 'layer': 2, 'event': 2, 'link': 2, 'direction': 2, 'location': 2, 'touch': 2, 'pow': 2, 'reaction': 2, 'plenty': 2, 'tab': 2, 'picture': 2, 'character': 2, 'recognition': 1})
# pop Counter({'menu': 2, 'video': 2, 'recommendation': 1})
# raise Counter({'million': 37, 'round': 15, 'Oct': 12, 'M': 4, 'quarter': 2, '15': 2, 'fund': 2, 'B': 1, 'billion': 1, 'question': 1, 'A': 1, 'Free': 1})
# top Counter({'user': 1})
# host Counter({'more': 1, 'day': 1, 'event': 1})
# debut Counter({'iteration': 5, 'update': 2, 'Watch': 2, 'be': 1, 'version': 1})
# expand Counter({'service': 6, 'relationship': 5, '-PRON-': 2, 'feature': 1, 'lineup': 1})
# include Counter({'trial': 5, 'set': 2, 'animal': 2, 'emoji': 2, 'thank': 2, 'fix': 2, 'those': 2, 'support': 2, 'bug': 2, 'app': 2, 'return': 2, 'option': 1, 'stunt': 1, 'recognition': 1})
# teach Counter({'user': 1})
# release Counter({'update': 20, '13.2': 6, 'extension': 6, 'that': 2, 'feature': 2, 'ios': 2, 'Capitan': 2, 'platform': 2, 'version': 2, 'set': 1})
# inform Counter({'user': 1})
# filter Counter({'comment': 1})
# dampen Counter({'potential': 1})
# Load Counter({'more': 1})
# @sarahintampa Counter({'year': 2})
# involve Counter({'Photos': 2})
# receive Counter({'feature': 4, 'update': 4, 'emoji': 2, 'upgrade': 2, 'protection': 2})
# support Counter({'decision': 2, 'storage': 2, 'orientation': 2, 'speed': 2, '-PRON-': 2, 'tool': 2})
# use Counter({'that': 7, 'bitcoin': 6, 'opportunity': 6, 'signal': 6, 'feature': 6, 'shadow': 5, 'font': 4, 'Safari': 4, '-PRON-': 3, '6s': 2, 'surface': 2, 'monitor': 2, 'sensor': 2, 'camera': 2, 'more': 2, 'phrase': 2, 'device': 2, 'Capitan': 2, 'Mac': 2, 'Metal': 2, 'line': 2, 'laptop': 2, 'favicon': 2, 'format': 2, 'Mail': 2, '’': 2, 'app': 2, 'machine': 2, 'touchid': 2, 'release': 2, 'system': 2, 'voice': 2, 'Siri': 2, 'geolocation': 2, 'program': 2, 'imagery': 1, 'technique': 1, 'obsession': 1, 'AI': 1})
# record Counter({'movement': 2, 'video': 2})
# welcome Counter({'-PRON-': 4, 'change': 2})
# play Counter({'game': 3, 'who': 2})
# ’s Counter({'lot': 8, 'one': 5, 'patch': 4, 'setting': 2, 'goal': 2, 'choice': 2, 'chance': 2, 'something': 2, 'effect': 2, 'beta': 2, 'much': 2, 'feat': 2, 'case': 2, 'change': 2, 'trailer': 1, 'everything': 1, 'opposite': 1, 'time': 1})
# update Counter({'device': 6, 'page': 2, '9to5mac': 2, 'ios': 2, 'pro': 1, 'list': 1})
# show Counter({'rate': 2, 'sign': 2, 'level': 2, 'willingness': 2, '-PRON-': 2, 'age': 2, 'people': 2, 'mail': 2, 'content': 2})
# ios Counter({'account': 2})
# roll Counter({'watchOS': 2, 'eye': 2, 'system': 2, 'in': 1, 'notice': 1, 'Preview': 1, 'app': 1})
# address Counter({'problem': 2, 'couple': 2, 'that': 2})
# fix Counter({'bug': 6, 'lot': 2, 'that': 2, 'hole': 2})
# cause Counter({'crash': 2})
# run Counter({'Office': 2, 'display': 2, 'app': 2, 'Yosemite': 2, 'Capitan': 2, 'software': 2, 'tvo': 2, 'watchOS': 2})
# have Counter({'word': 6, 'piece': 6, 'customer': 6, 'family': 5, 'advantage': 4, 'tab': 4, 'event': 4, 'bug': 4, 'that': 3, 'lot': 3, 'chance': 3, 'update': 2, 'connector': 2, 'sort': 2, 'finish': 2, 'edge': 2, 'hole': 2, 'use': 2, 'browsing': 2, 'GB': 2, '—': 2, 'excuse': 2, 'arrangement': 2, 'bezel': 2, 'ability': 2, 'leg': 2, 'hope': 2, 'drawback': 2, 'user': 2, 'Safari': 2, 'disparity': 2, 'weakness': 2, 'trouble': 2, 'access': 2, 'feedback': 2, 'backup': 2, 'mode': 2, 'in': 2, 'tweak': 1, '-PRON-': 1, 'time': 1, 'play': 1, 'source': 1, 'ambition': 1, 'presence': 1, 'application': 1, 'visitor': 1, 'attorney': 1, 'more': 1, 'pizzazz': 1})
# found Counter({'business': 1, 'SiliconFilter': 1})
# cover Counter({'thing': 6, 'third': 2, 'Photos': 2, 'ecosystem': 1, 'Apple': 1, 'enterprise': 1, 'paper': 1, 'technology': 1})
# make Counter({'sense': 9, 'effortless': 6, 'way': 6, 'tourism': 5, 'jump': 4, '-PRON-': 4, 'lot': 4, 'name': 2, 'room': 2, 'leap': 2, 'connection': 2, 'decision': 2, 'call': 2, 'laptop': 2, 'tablet': 2, 'checklist': 2, 'channel': 2, 'video': 2, 'round': 2, 'address': 2, 'change': 1, 'review': 1, 'tool': 1, 'application': 1})
# Owns Counter({'share': 1})
# grade Counter({'opt': 1})
# request Counter({'feature': 1})
# contain Counter({'blend': 2, 'Fusion': 1})
# do Counter({'that': 6, 'what': 6, 'run': 5, 'work': 4, 'lot': 4, 'this': 2, 'way': 2, 'shit': 2, '-PRON-': 2, 'Disneyland': 1, 'everything': 1, 'quantum': 1})
# get Counter({'business': 5, 'crew': 5, 'support': 5, '-PRON-': 4, 'improvement': 4, 'feature': 4, 'look': 3, 'power': 2, 'rap': 2, 'parity': 2, 'utility': 2, 'stupid': 2, 'lcd': 2, 'iPad': 2, 'experience': 2, 'invite': 2, 'idea': 2, 'series': 2, 'name': 2, 'help': 2, 'information': 2, 'update': 2, 'build': 2, 'this': 1, 'group': 1, 'ability': 1, 'backlash': 1, 'slice': 1, 'ton': 1, 'more': 1, 'everyone': 1, 'insurance': 1, 'minute': 1, 'report': 1, 'unit': 1, 'light': 1, 'approval': 1, 'chance': 1, 'restaurant': 1, 'tier': 1})
# tweak Counter({'change': 1})
# comply Counter({'event': 1})
# unveil Counter({'Pixel': 6, 'lineup': 6, 'drone': 5, 'Capitan': 2, 'version': 1, 'class': 1})
# watch Counter({'video': 4, 'OS': 2, 'lot': 2, 'this': 1})
# turn Counter({'protection': 8, 'tap': 2, '-PRON-': 2, 'Mac': 2, 'volume': 2, 'three': 2, 'review': 1, 'heat': 1})
# Siri Counter({'review': 1})
# select Counter({'user': 1})
# suspend Counter({'response': 1, 'world': 1})
# disable Counter({'app': 2, 'Fi': 2})
# eavesdropping Counter({'Jul': 1})
# tell Counter({'-PRON-': 4, 'Jul': 1, 'theater': 1})
# notice Counter({'-PRON-': 2, 'methodology': 1})
# enable Counter({'tap': 2, '-PRON-': 2, 'option': 2, 'feature': 1})
# find Counter({'state': 2, 'app': 2, 'cursor': 2, 'file': 2, '-PRON-': 2, 'firm': 1, 'friend': 1, 'video': 1, 'one': 1, 'exoplanet': 1, 'need': 1})
# leave Counter({'door': 2, 'Apple': 1})
# require Counter({'power': 2, 'feedback': 2, '-PRON-': 2, 'configuration': 2, 'app': 1})
# prove Counter({'feature': 1})
# fly Counter({'Falcon': 1, 'Apple': 1})
# visit Counter({'Wars': 1})
# try Counter({'thing': 2, 'test': 2, '-PRON-': 2, 'system': 2, 'attraction': 1})
# mean Counter({'what': 2, 'lineup': 2, '15': 1, 'cooperation': 1, 'nab': 1})
# talk Counter({'program': 1})
# invite Counter({'member': 2, 'developer': 1})
# attend Counter({'School': 6, 'conference': 1})
# eliminate Counter({'light': 2})
# improve Counter({'quality': 2, 'performance': 2, 'result': 1, 'tech': 1, 'suit': 1})
# change Counter({'zone': 2, 'mode': 2, 'behavior': 2, 'way': 2, 'system': 2, 'business': 1})
# Romain Counter({'TechCrunch': 6})
# like Counter({'culture': 6, 'tracking': 2, '-PRON-': 2, '’s': 2})
# love Counter({'-PRON-': 6, 'Oct': 1})
# own Counter({'amount': 6, 'computer': 2})
# map Counter({'word': 6})
# hold Counter({'conference': 6, 'stock': 5, 'event': 3, 'Pro': 2, 'tablet': 2, 'pencil': 2, 'iPad': 2, '—': 2, 'day': 1})
# ipados Counter({'13.2': 6})
# feature Counter({'fix': 6, 'window': 2, 'icon': 2, 'point': 1})
# issue Counter({'release': 6, 'statement': 2, 'update': 2, 'patch': 2, 'fix': 2})
# easy Counter({'welcome': 6})
# empower Counter({'company': 6})
# ’ Counter({'bike': 6, 'surprise': 2, 'power': 2, 'scenario': 2, 'thing': 2, 'jump': 2, 'editor': 2, 'improvement': 2})
# simplify Counter({'management': 6})
# Bootstrapped Counter({'Doist': 6})
# pay Counter({'Moon': 6, 'friend': 2})
# pull Counter({'app': 6, 'bit': 2, '-PRON-': 2, 'information': 2, 'stunt': 1})
# crowdsource Counter({'location': 6})
# develop Counter({'game': 6, 'doubt': 2, 'something': 2})
# handle Counter({'everything': 6, 'file': 2, 'alignment': 2, 'pro': 2, 'address': 2})
# provide Counter({'service': 6, 'precision': 2, 'accessory': 2, 'experience': 2, 'navigation': 2, 'solution': 2, 'following': 2, 'update': 2, 'guide': 2, 'bed': 2, 'feature': 2, 'look': 2, 'coda': 1})
# build Counter({'service': 7, 'suitcase': 6, 'app': 6, 'community': 4, 'tablet': 2, 'car': 2, 'lake': 1})
# eat Counter({'what': 6})
# learn Counter({'Foodvisor': 6, 'third': 1})
# log Counter({'everything': 6})
# lose Counter({'weight': 6, 'connection': 2})
# follow Counter({'diet': 6, 'tradition': 2, 'instruction': 2})
# capture Counter({'photo': 6})
# track Counter({'device': 6, 'thing': 6, 'debris': 1})
# leverage Counter({'G': 6, 'Metal': 2})
# believe Counter({'who': 2})
# open Counter({'door': 2, 'side': 2, 'gate': 2, 'Siri': 2, 'drawer': 2, 'window': 2, 'tab': 2})
# ship Counter({'version': 2, 'processor': 2, 'update': 2})
# embrace Counter({'-PRON-': 2})
# save Counter({'-PRON-': 2, 'datum': 2, 'time': 2})
# invoke Counter({'-PRON-': 2})
# adjust Counter({'cadence': 2})
# tap Counter({'pencil': 2, '-PRON-': 2, 'button': 2})
# see Counter({'function': 2, 'performance': 2, 'what': 2, 'name': 2, 'update': 2, 'trend': 2, 'launch': 2})
# — Counter({'behavior': 2, 'improvement': 2, 'total': 2, 'peril': 2, 'version': 2})
# give Counter({'lot': 2, 'portrait': 2, 'side': 2, 'corner': 2, 'food': 2, 'people': 2, 'year': 2, 'access': 2, 'try': 2})
# reflect Counter({'tool': 2})
# instruct Counter({'developer': 2})
# implement Counter({'—': 2, 'change': 2})
# encourage Counter({'-PRON-': 2})
# tracking Counter({'accuracy': 2})
# plug Counter({'-PRON-': 2, 'microphone': 2})
# force Counter({'pencil': 2})
# slap Counter({'pencil': 2, 'this': 2})
# sketch Counter({'more': 2})
# call Counter({'finish': 2, 'feature': 2, 'what': 2})
# stop Counter({'pencil': 2})
# register Counter({'edge': 2})
# scratch Counter({'issue': 2})
# enhance Counter({'usability': 2})
# blow Counter({'device': 2})
# choose Counter({'action': 2, 'college': 1})
# manipulate Counter({'layer': 2})
# feel Counter({'heck': 2, 'same': 2, '-PRON-': 2, 'more': 1})
# solve Counter({'lot': 2, 'Cube': 2})
# hit Counter({'target': 2, 'shelf': 1, 'milestone': 1})
# deliver Counter({'experience': 2, 'mode': 2})
# noise Counter({'cancel': 2})
# produce Counter({'sound': 2, 'startup': 1})
# charge Counter({'iPhones': 2})
# want Counter({'what': 3, 'system': 2})
# display Counter({'resolution': 2, 'pdf': 2, 'message': 2})
# serve Counter({'7.5w': 2, 'option': 2, 'enterprise': 1})
# excite Counter({'-PRON-': 2})
# need Counter({'room': 2, 'what': 2, 'drive': 2, 'bell': 2, '-PRON-': 1})
# performance Counter({'model': 2})
# discern Counter({'what': 2})
# affect Counter({'performance': 2, 'bash': 2})
# encounter Counter({'zero': 2})
# edit Counter({'photo': 2, 'picture': 2})
# achieve Counter({'end': 2})
# dribble Counter({'-PRON-': 2})
# crystallize Counter({'fact': 2})
# go Counter({'what': 5, 'dad': 2, 'screen': 2})
# write Counter({'word': 2})
# crash Counter({'on': 4, 'word': 2, 'Safari': 2, 'browser': 2, 'touch': 2})
# demand Counter({'switching': 2})
# point Counter({'outward': 2})
# know Counter({'that': 2, 'what': 2})
# curve Counter({'corner': 2})
# lay Counter({'-PRON-': 2, 'vision': 1})
# cede Counter({'millimeter': 2})
# cut Counter({'head': 4, 'chin': 2})
# balance Counter({'design': 2})
# keep Counter({'exterior': 2, 'experience': 2, 'ten': 2, 'everyone': 2, 'balance': 1, '-PRON-': 1})
# attach Counter({'accessory': 2})
# test Counter({'feature': 4, 'model': 2, 'reality': 2, 'clipboard': 2, 'release': 2})
# gain Counter({'functionality': 2, 'control': 2})
# exhibit Counter({'issue': 2})
# gate Counter({'Apple': 2})
# bash Counter({'passage': 2})
# pair Counter({'-PRON-': 2})
# dispel Counter({'confusion': 2})
# unleash Counter({'-PRON-': 2})
# unlock Counter({'Mac': 4, 'interface': 2})
# blend Counter({'specificity': 2})
# detach Counter({'keyboard': 2})
# set Counter({'Pencil': 2, 'shortcut': 2, 'foot': 1})
# adapt Counter({'world': 2})
# steal Counter({'attention': 2})
# move Counter({'astronaut': 5, 'way': 2, 'window': 2, 'file': 2})
# furnished Counter({'Testing': 2})
# miss Counter({'news': 2, 'direction': 2})
# sum Counter({'-PRON-': 2})
# spray Counter({'solution': 2})
# contributin Counter({'Arrives': 2})
# diversify Counter({'cohort': 2})
# shift Counter({'up': 2})
# Found Counter({'Buyer': 2})
# sell Counter({'vehicle': 5, '-PRON-': 2, 'laptop': 2, 'unit': 1})
# put Counter({'information': 2, '-PRON-': 2, 'lot': 2})
# demonstrate Counter({'evolution': 2, 'gesture': 2, 'advantage': 2})
# remember Counter({'Leopard': 2})
# expect Counter({'what': 2, 'much': 1})
# confirm Counter({'something': 2})
# list Counter({'each': 2})
# offload Counter({'some': 2})
# load Counter({'website': 4, 'list': 2, '-PRON-': 2, 'page': 2, 'bit': 2, 'more': 1})
# enter Counter({'password': 2, 'era': 1})
# alter Counter({'file': 2})
# reboot Counter({'-PRON-': 4, 'Mac': 2, 'one': 2})
# access Counter({'partition': 2})
# install Counter({'app': 2, 'beta': 2})
# hand Counter({'access': 2})
# instal Counter({'Capitan': 2})
# stack Counter({'window': 2, 'challenge': 1})
# drag Counter({'window': 4, 'app': 2, 'line': 2})
# shake Counter({'mouse': 2})
# divide Counter({'screen': 2})
# resize Counter({'app': 2, 'window': 2})
# understand Counter({'input': 2, 'intention': 1})
# pin Counter({'tab': 4})
# mute Counter({'tab': 2})
# draft Counter({'email': 2})
# delete Counter({'-PRON-': 2, 'icon': 2})
# suggest Counter({'-PRON-': 2})
# acquire Counter({'Embark': 2, 'Barrel': 2, 'company': 1, 'Streamlabs': 1, 'Oct': 1, 'Fitbit': 1, 'IKinema': 1})
# plan Counter({'itinerary': 2})
# name Counter({'people': 2, 'version': 2, 'scheme': 2})
# download Counter({'installer': 4, '-PRON-': 2, 'build': 2, 'rest': 1})
# merge Counter({'x': 2, 'site': 1})
# enjoy Counter({'view': 2})
# catch Counter({'breath': 2})
# focus Counter({'effort': 5})
# prompt Counter({'startup': 5, 'response': 2})
# ask Counter({'who': 5, 'score': 2, 'anyone': 1})
# best Counter({'driver': 5})
# launc Counter({'’s': 5})
# win Counter({'market': 5, '10b': 1, 'contract': 1})
# upscale Counter({'Oct': 5})
# replace Counter({'podcast': 5, 'bunch': 2, 'deposit': 1})
# complete Counter({'season': 6})
# detail Counter({'which': 5})
# astronaut Counter({'NASA': 5})
# land Counter({'Starship': 5})
# landing Counter({'Oct': 5})
# shed Counter({'intend': 5})
# start Counter({'Oct': 5, 'spring': 2})
# discuss Counter({'state': 5, 'path': 1})
# think Counter({'what': 5})
# lead Counter({'MobileCrunch': 1})
# break Counter({'hundred': 1, '-PRON-': 1})
# smartphone Counter({'prototype': 1})
# reach Counter({'valuation': 1})
# combine Counter({'reality': 1})
# replicate Counter({'big': 1})
# appear Counter({'series': 1})
# pick Counter({'feature': 2, 'support': 1, 'million': 1, 'speed': 1})
# tear Counter({'gadget': 1})
# part Counter({'way': 1})
# plant Counter({'die': 1})
# evaluate Counter({'risk': 1})
# publish Counter({'list': 1})
# reinvent Counter({'-PRON-': 1})
# cement Counter({'spot': 1})
# overlay Counter({'content': 1})
# integrate Counter({'api': 2, 'all': 1, 'product': 1})
# tinker Counter({'who': 2})
# push Counter({'patch': 2})
# nab Counter({'-PRON-': 2})
# grab Counter({'one': 2, 'title': 2})
# assure Counter({'user': 2})
# report Counter({'vulnerability': 2, 'timeframe': 2, 'victim': 1})
# remote Counter({'exploit': 2})
# configure Counter({'service': 2, 'access': 2})
# protect Counter({'-PRON-': 2})
# close Counter({'hole': 2, 'tab': 2})
# join Counter({'convos': 4, 'TechCrunch': 1, '-PRON-': 1})
# let Counter({'devs': 2, 'word': 2, 'share': 1})
# order Counter({'food': 2})
# send Counter({'link': 2, '-PRON-': 2, 'location': 2, 'message': 2, 'text': 2, 'url': 2, 'letter': 1})
# translate Counter({'word': 2})
# hide Counter({'message': 2})
# swipe Counter({'finger': 2})
# reveal Counter({'content': 2})
# gear Counter({'Yosemite': 2})
# showcase Counter({'iPad': 2})
# echo Counter({'claim': 2})
# hear Counter({'rumbling': 2, 'rumor': 2})
# peg Counter({'which': 2})
# differentiate Counter({'lineup': 2, 'device': 2})
# represent Counter({'half': 2, 'change': 1})
# switch Counter({'browsing': 2})
# desktop Counter({'action': 2})
# bother Counter({'-PRON-': 2})
# behold Counter({'name': 2})
# perform Counter({'task': 2})
# free Counter({'space': 2, 'peech': 1})
# sync Counter({'desktop': 2, 'file': 2})
# anticipate Counter({'future': 2})
# equal Counter({'something': 2})
# tackle Counter({'feature': 4, 'ios': 2, 'housing': 1})
# ramp Counter({'effort': 1})
# hundred Counter({'launch': 1})
# source Counter({'framework': 1})
# eithe Counter({'Google': 1})
# say Counter({'-PRON-': 3})
# block Counter({'total': 1})
# refresh Counter({'processor': 1})
# automate Counter({'aspect': 1, 'management': 1})
# microservice Counter({'Oct': 1, 'Microsoft': 1})
# click Counter({'button': 1})
# mark Counter({'return': 1})
# renew Counter({'contract': 2})
# smart Counter({'Nexkey': 1})
# speed Counter({'web': 1})
# recognize Counter({'-PRON-': 1})
# email Counter({'-PRON-': 1})
# invoice Counter({'Stampli': 1})
# identify Counter({'podcast': 1})
# remix Counter({'file': 1})
# ha Counter({'Etherington': 1})
# shrink Counter({'game': 1})
# bonker Counter({'Anthony': 1})
# settle Counter({'treatment': 1})
# kick Counter({'day': 1})
# star Counter({'Galifianakis': 1})
# scale Counter({'product': 1})
# spur Counter({'people': 1})
# Si Counter({'’': 1})
# review Counter({'-PRON-': 1})
# consider Counter({'move': 2})
# pursue Counter({'course': 2})
# resemble Counter({'bulk': 2})
# present Counter({'space': 2})
# outweigh Counter({'negative': 2})
# draw Counter({'criticism': 2})
# upcoming Counter({'release': 2})
# eligible Counter({'device': 2})
# ensure Counter({'download': 2})
# backup Counter({'Mac': 2})
# clone Counter({'drive': 2})
# pack Counter({'lot': 2, 'update': 2})
# upgrade Counter({'brainer': 2})
# read Counter({'review': 4, 'Facebook': 1})
# trigger Counter({'-PRON-': 4})
# bake Counter({'feature': 2})
# compile Counter({'stream': 2})
# generate Counter({'album': 2})
# return Counter({'photo': 2})
# browse Counter({'web': 2})
# mention Counter({'feature': 2, 'macos': 2})
# copy Counter({'something': 2})
# paste Counter({'-PRON-': 2})
# optimize Counter({'storage': 2})
# upload Counter({'file': 2})
# port Counter({'feature': 2})
# revolutionize Counter({'macos': 2})
# patch Counter({'vulnerability': 4})
# arrive Counter({'day': 2})
# wrap Counter({'thing': 2})
# parse Counter({'sentence': 2})
# fill Counter({'side': 2, 'space': 2})
# surprise Counter({'audience': 2})
# render Counter({'performance': 2})
# ban Counter({'ad': 1})
# disallow Counter({'any': 1})
# inspire Counter({'kind': 1})
# pervade Counter({'life': 1})
# hunt Counter({'water': 1})
# market Counter({'Oct': 1})
# heed Counter({'concern': 1})
# restore Counter({'text': 1})
# connect Counter({'device': 1})
# number Counter({'Oct': 1})
# feast Counter({'eye': 1})
# observe Counter({'Oct': 1})
# gadget Counter({'Oct': 1})
# funky Counter({'gadget': 1})
# impact Counter({'issue': 1})
# ent Counter({'more': 1})
# abandon Counter({'name': 2})
# describe Counter({'initiative': 2})
# rebrande Counter({'system': 2, 'x': 2})
# drop Counter({'Mac': 2})
# unify Counter({'system': 2})
# clear Counter({'cache': 2})
# reload Counter({'website': 2})
# ordering Counter({'platform': 1})
# thank Counter({'-PRON-': 4})
# govern Counter({'principle': 1})
# screw Counter({'relationship': 1})
# commit Counter({'1b': 1})
# seek Counter({'“': 1})
# surpass Counter({'sale': 1})
# score Counter({'film': 1})
# approve Counter({'merger': 2})
# Ensuring Counter({'politician': 1})
# decide Counter({'-PRON-': 1})
# sit Counter({'one': 1})
# bolster Counter({'device': 1})
# thrust Counter({'-PRON-': 1})

# %% [markdown]
# What can you say about the distribution of predicates and the subjects and objects? Does this look familair?

# %% [markdown]
# ## End of this Notebook
